# %% [markdown]
# ### Correct way to download and load a matlab file

# %%
from pathlib import Path
from deep_gp.utilities import download_from_google_drive, load_matlab_file

url = "https://drive.google.com/uc?id=1jhWL3YUHvXIaftia4qeAyDwVxo6j1alk"
out = Path("elevators.mat")

download_from_google_drive(url, out)
data = load_matlab_file(out)
# Out:
# elevators.mat already exists, not downloading.
# dict_keys(['__header__', '__version__', '__globals__', 'data', 'None', '__function_workspace__'])

# %%
data['data']
# Out:
# array([[-2.94204229e+02, -2.72012169e+01, -2.59924092e-01, ...,
#         -3.01222965e-08,  5.65756973e-05, -4.19588509e-02],
#        [ 4.56795771e+02,  8.79878306e+00,  4.20075908e-01, ...,
#         -3.01222965e-08, -1.43424303e-04,  5.33513289e-02],
#        [ 1.27795771e+02,  8.79878306e+00,  7.00759082e-02, ...,
#         -3.01222965e-08, -6.43424303e-04,  3.29604706e-01],
#        ...,
#        [ 2.37957708e+01, -1.12012169e+01,  1.30075908e-01, ...,
#         -3.01222965e-08,  5.65756973e-05,  6.75880942e-01],
#        [-9.52042292e+01, -1.52012169e+01,  5.00075908e-01, ...,
#         -3.01222965e-08,  3.56575697e-04, -2.04477780e-01],
#        [ 8.07957708e+01,  8.79878306e+00,  3.40075908e-01, ...,
#         -3.01222965e-08,  4.56575697e-04, -4.19588509e-02]],
#       shape=(16599, 19))
